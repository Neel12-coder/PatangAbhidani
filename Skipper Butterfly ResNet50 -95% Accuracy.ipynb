# %%
# !unzip "/content/drive/MyDrive/skipper.zip"

# %%
from pathlib import Path
from fastai.vision import *
import numpy as np
path = Path('/content/skipper')
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train='.', valid_pct=0.2,
                                  ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
vc = pd.value_counts(data.train_ds.y.items, sort=True)
vc.index = data.classes
vc[:20]
# Out:
# Actinor radians                308
# Aeromachus dubius              297
# Aeromachus jhora               271
# Aeromachus kali                223
# Aeromachus pygmaeus            216
# Aeromachus stigmata            213
# Ampittia dioscorides           210
# Ampittia subvittatus           203
# Ancistroides nigrita           193
# Apostictopterus fuliginosus    181
# Arnetta atkinsoni              177
# Arnetta mercara                173
# Arnetta vindhiana              169
# Astictopterus jama             160
# Badamia exclamationis          141
# Baorini spp                    133
# Baoris chapmani                133
# Baoris farri                   132
# Baoris pagana                  126
# Baoris unicolor                123
# dtype: int64

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (8716 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Halpe spp,Halpe spp,Halpe spp,Halpe spp,Halpe spp
# Path: /content/skipper;
#
# Valid: LabelList (2178 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Udaspes folus,Ampittia dioscorides,Baracus hampsoni,Notocrypta curvifascia,Oriens goloides
# Path: /content/skipper;
#
# Test: None

# %%
data.classes
# Out:
# ['Actinor radians',
#  'Aeromachus dubius',
#  'Aeromachus jhora',
#  'Aeromachus kali',
#  'Aeromachus pygmaeus',
#  'Aeromachus stigmata',
#  'Ampittia dioscorides',
#  'Ampittia subvittatus',
#  'Ancistroides nigrita',
#  'Apostictopterus fuliginosus',
#  'Arnetta atkinsoni',
#  'Arnetta mercara',
#  'Arnetta vindhiana',
#  'Astictopterus jama',
#  'Badamia exclamationis',
#  'Baorini spp',
#  'Baoris chapmani',
#  'Baoris farri',
#  'Baoris pagana',
#  'Baoris unicolor',
#  'Baracus hampsoni',
#  'Baracus septentrionum',
#  'Baracus subditus',
#  'Bibasis mahintha',
#  'Bibasis sena',
#  'Borbo bevani',
#  'Borbo cinnara',
#  'Burara amara',
#  'Burara anadi',
#  'Burara gomata',
#  'Burara harisa',
#  'Burara jaina',
#  'Burara oedipodea',
#  'Burara vasutana',
#  'Caltoris aurociliata',
#  'Caltoris canaraica',
#  'Caltoris kumara',
#  'Caltoris philippina',
#  'Caltoris spp',
#  'Caltoris tulsi',
#  'Capila jayadeva',
#  'Capila lidderdali',
#  'Capila phanaeus',
# ...

# %%
data.show_batch(rows=3, figsize=(7, 8))

# %%
from fastai.metrics import error_rate # 1 - accuracy
learn = create_cnn(data, models.resnet34, metrics=accuracy)
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
defaults.device = torch.device('cuda') # makes sure the gpu is used
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.521335</td>
#       <td>3.441208</td>
#       <td>0.313590</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.261725</td>
#       <td>2.106057</td>
#       <td>0.494031</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.324410</td>
#       <td>1.690832</td>
#       <td>0.568411</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.781862</td>
#       <td>1.462469</td>
#       <td>0.618457</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.484739</td>
#       <td>1.270205</td>
#       <td>0.657025</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
from fastai.metrics import error_rate # 1 - accuracy
learn = create_cnn(data, models.vgg16_bn, metrics=accuracy)
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# ...

# %%
defaults.device = torch.device('cuda') # makes sure the gpu is used
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.461407</td>
#       <td>3.426309</td>
#       <td>0.313131</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.164135</td>
#       <td>2.091385</td>
#       <td>0.498163</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.271572</td>
#       <td>1.688303</td>
#       <td>0.556015</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.804041</td>
#       <td>1.462662</td>
#       <td>0.610652</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.460248</td>
#       <td>1.290267</td>
#       <td>0.643710</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
from fastai.metrics import error_rate # 1 - accuracy
learn = create_cnn(data, models.vgg19_bn, metrics=accuracy)
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/vgg19_bn-c79401a0.pth" to /root/.cache/torch/hub/checkpoints/vgg19_bn-c79401a0.pth
# ...

# %%
defaults.device = torch.device('cuda') # makes sure the gpu is used
learn.fit_one_cycle(10)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [2/10 04:24<17:36]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
from fastai.metrics import error_rate # 1 - accuracy
learn = create_cnn(data, models.resnet50, metrics=accuracy)
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...

# %%
defaults.device = torch.device('cuda') # makes sure the gpu is used
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.323899</td>
#       <td>2.602315</td>
#       <td>0.448830</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.645708</td>
#       <td>1.830747</td>
#       <td>0.547040</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.983813</td>
#       <td>1.418866</td>
#       <td>0.634695</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.449189</td>
#       <td>1.113969</td>
#       <td>0.702616</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.152650</td>
#       <td>0.969266</td>
#       <td>0.739789</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.unfreeze() # must be done before calling lr_find
learn.lr_find()
learn.recorder.plot()f
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Actinor radians', 'Aeromachus dubius', 'Aeromachus jhora', 'Aeromachus kali', 'Aeromachus pygmaeus', 'Aeromachus stigmata', 'Ampittia dioscorides', 'Ampittia subvittatus', 'Ancistroides nigrita', 'Apostictopterus fuliginosus', 'Arnetta atkinsoni', 'Arnetta mercara', 'Arnetta vindhiana', 'Astictopterus jama', 'Badamia exclamationis', 'Baorini spp', 'Baoris chapmani', 'Baoris farri', 'Baoris pagana', 'Baoris unicolor', 'Baracus hampsoni', 'Baracus septentrionum', 'Baracus subditus', 'Bibasis mahintha', 'Bibasis sena', 'Borbo bevani', 'Borbo cinnara', 'Burara amara', 'Burara anadi', 'Burara gomata', 'Burara harisa', 'Burara jaina', 'Burara oedipodea', 'Burara vasutana', 'Caltoris aurociliata', 'Caltoris canaraica', 'Caltoris kumara', 'Caltoris philippina', 'Caltoris spp', 'Caltoris tulsi', 'Capila jayadeva', 'Capila lidderdali', 'Capila phanaeus', 'Capila zennara', 'Caprona agama', 'Caprona alida', 'Caprona ransonnettii', 'Carcharodus alceae', 'Carterocephalus avanti', 'Celaenorrhinus
# ...

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
# ...

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.444325</td>
#       <td>0.690603</td>
#       <td>0.817347</td>
#       <td>01:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.807886</td>
#       <td>0.958591</td>
#       <td>0.753098</td>
#       <td>01:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.924455</td>
#       <td>0.723753</td>
#       <td>0.802662</td>
#       <td>01:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.706522</td>
#       <td>0.485714</td>
#       <td>0.863240</td>
#       <td>01:48</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.580533</td>
#       <td>0.519085</td>
#       <td>0.858192</td>
#       <td>01:48</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('resnet-50_SKIPPER')

# %%
from fastai.imports import *
from fastai import *
from fastai.vision import *
from fastai.metrics import error_rate

path = Path("/content/skipper")

data2 = ImageDataBunch.single_from_classes(path, classes, size=224).normalize(imagenet_stats)
learn = create_cnn(data2, models.resnet50)

# %%
img = open_image("/content/skipper/Coeliadinae/Badamia/Badamia exclamationis/579-0.jpg")
learn = learn.load("/content/skipper/models/resnet-50_SKIPPER")
img.show()
pred_class, pred_idx, outputs = learn.predict(img)
print(str(pred_class).capitalize())
# Out:
# Badamia exclamationis

# %%
img = open_image("/content/skipper/Heteropterinae/Carterocephalus/Carterocephalus avanti/2161-0.jpg")
learn = learn.load("/content/skipper/models/resnet-50_SKIPPER")
img.show()
pred_class, pred_idx, outputs = learn.predict(img)
print(str(pred_class).capitalize())
# Out:
# Carterocephalus avanti

# %%
img = open_image("/content/skipper/Pyrginae/Caprona/Caprona agama/2114-0.jpg")
learn = learn.load("/content/skipper/models/resnet-50_SKIPPER")
img.show()
pred_class, pred_idx, outputs = learn.predict(img)
print(str(pred_class).capitalize())
# Out:
# Caprona agama

# %%
img = open_image("/content/skipper/Pyrginae/Spialia/Spialia galba/620-0.jpg")
learn = learn.load("/content/skipper/models/resnet-50_SKIPPER")
img.show()
pred_class, pred_idx, outputs = learn.predict(img)
print(str(pred_class).capitalize())
# Out:
# Spialia galba

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
interp.plot_confusion_matrix()

# %%
#PLOTTING TOP LOSSES
interp.plot_top_losses(4, figsize=(15,15))
